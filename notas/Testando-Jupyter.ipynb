# %% [markdown]
# # Este código é meramente um exemplo apenas para testar o jupyter.

# %%
1 + 2 + 3
# Out:
# 6

# %%
2 ** 8
# Out:
# 256

# %%
print('teste jupyter!')
# Out:
# teste jupyter!

# %% [markdown]
# # Operadores

# %%
1 + 2
# Out:
# 3

# %%
2 * 4
# Out:
# 8

# %%
3 / 5
# Out:
# 0.6

# %% [markdown]
# # Estrutura de controle

# %%
a = 2

# %%
b = 3

# %%
a + b
# Out:
# 5

# %%
_ ** 3
# Out:
# 125

# %%
_ / 5
# Out:
# 25.0

# %%
a = 3
b = 7

a, b = b, a
print(a, b)
# Out:
# 7 3
